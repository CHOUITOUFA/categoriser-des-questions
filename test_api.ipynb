# %%
# Python libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Mohaw\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Mohaw\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Mohaw\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
#Read la data frame
df=pd.read_csv(filepath_or_buffer='QueryResults(2).csv')
df
# Out:
#                                                    Title  \
# 0      angular: assigning ng-options dynamically, str...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49995  Delete files older than 24 hours and empty dir...
# 49996  MVC 4 Jquery Datepicker Initializes on Multipl...
# 49997  How to change the default redirect behaviour o...
# 49998          puppet how to manage service with only if
# 49999  construct a data frame in R from combining inf...
#
#                                                     Body  \
# 0      <p>I am building an inline editable form.</p>\...
# 1      <p>I'm going to operate off the assumption tha...
# 2      <p>Use to add the textarea's classes to tinymc...
# 3      <p>It seems to me that unless the compiler can...
# 4      <blockquote>\n  <p>Is the compiler free to ass...
# ...                                                  ...
# 49995  <p>I have these cron tasks to manage the autom...
# 49996  <p>I'm using VS2010, MVC 4 with Razor, JQuery ...
# 49997  <p>I am working on an <code>ASP.NET MVC 4</cod...
# 49998  <p>Can some one help me with puppet, I want to...
# 49999  <p>I have a data frame consisting of two colum...
#
#                                                     Tags        Id  Score  \
# 0                        <javascript><angularjs><select>  20060436      1
# 1                                                    NaN  20060437      1
# 2                                                    NaN  20060438      4
# 3                                                    NaN  20060439      4
# 4                                                    NaN  20060440     16
# ...                                                  ...       ...    ...
# 49995                                       <find><cron>  20107249     -1
# 49996      <jquery><asp.net-mvc-4><jquery-ui-datepicker>  20107251      0
# 49997  <asp.net-mvc-4><forms-authentication><simpleme...  20107253      0
# 49998            <service><puppet><configurationmanager>  20107254      1
# 49999                                                <r>  20107255      0
#
#        ViewCount  FavoriteCount  AnswerCount
# 0          271.0            NaN          1.0
# 1            NaN            NaN          NaN
# 2            NaN            NaN          NaN
# 3            NaN            NaN          NaN
# 4            NaN            NaN          NaN
# ...          ...            ...          ...
# 49995     2598.0            0.0          3.0
# 49996      154.0            NaN          0.0
# 49997      584.0            NaN          0.0
# 49998     2285.0            NaN          1.0
# 49999       85.0            NaN          2.0
#
# [50000 rows x 8 columns]

# %%
df.head(5)
# Out:
#                                                Title  \
# 0  angular: assigning ng-options dynamically, str...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 Body  \
# 0  <p>I am building an inline editable form.</p>\...
# 1  <p>I'm going to operate off the assumption tha...
# 2  <p>Use to add the textarea's classes to tinymc...
# 3  <p>It seems to me that unless the compiler can...
# 4  <blockquote>\n  <p>Is the compiler free to ass...
#
#                               Tags        Id  Score  ViewCount  FavoriteCount  \
# 0  <javascript><angularjs><select>  20060436      1      271.0            NaN
# 1                              NaN  20060437      1        NaN            NaN
# 2                              NaN  20060438      4        NaN            NaN
# 3                              NaN  20060439      4        NaN            NaN
# 4                              NaN  20060440     16        NaN            NaN
#
#    AnswerCount
# 0          1.0
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.tail(5)
# Out:
#                                                    Title  \
# 49995  Delete files older than 24 hours and empty dir...
# 49996  MVC 4 Jquery Datepicker Initializes on Multipl...
# 49997  How to change the default redirect behaviour o...
# 49998          puppet how to manage service with only if
# 49999  construct a data frame in R from combining inf...
#
#                                                     Body  \
# 49995  <p>I have these cron tasks to manage the autom...
# 49996  <p>I'm using VS2010, MVC 4 with Razor, JQuery ...
# 49997  <p>I am working on an <code>ASP.NET MVC 4</cod...
# 49998  <p>Can some one help me with puppet, I want to...
# 49999  <p>I have a data frame consisting of two colum...
#
#                                                     Tags        Id  Score  \
# 49995                                       <find><cron>  20107249     -1
# 49996      <jquery><asp.net-mvc-4><jquery-ui-datepicker>  20107251      0
# 49997  <asp.net-mvc-4><forms-authentication><simpleme...  20107253      0
# 49998            <service><puppet><configurationmanager>  20107254      1
# 49999                                                <r>  20107255      0
#
#        ViewCount  FavoriteCount  AnswerCount
# 49995     2598.0            0.0          3.0
# 49996      154.0            NaN          0.0
# 49997      584.0            NaN          0.0
# 49998     2285.0            NaN          1.0
# 49999       85.0            NaN          2.0

# %%
df.sample(20)
# Out:
#                                                    Title  \
# 19387                                                NaN
# 26446                                                NaN
# 31075                                                NaN
# 234    Complex number computational error grows as th...
# 30400   Looping to display on LEDs HCS12 microcontroller
# 47945               What does this function do , Haskell
# 44562                                                NaN
# 27341                                                NaN
# 37845                                                NaN
# 13378               Find maximum element from two arrays
# 16590                                                NaN
# 21649                          oauth_callback on Android
# 33962  React Component, validate the child's componen...
# 32027  How can I create a .properties file in folder/...
# 28094                                                NaN
# 15727                                                NaN
# 12888  insertion sort in objective c is not returning...
# 15325                      Do zombies exist ... in .NET?
# 32304       Not able to Connect to hbase through phoenix
# 22251  In what way is this jStorage Object different ...
#
#                                                     Body  \
# 19387  <p>I am the developer of <a href="https://gith...
# 26446  <p>I don't remember offhand if there's a built...
# 31075  <p>With access to the CSV generation, here's o...
# 234    <p>If I have two small complex matrices, the c...
# 30400  <p>hello i am trying to do a loop in assembly ...
# 47945  <p>I need an algorithm that converts bin to de...
# 44562  <p>Your code has a serious problem.  Specifica...
# 27341  <p>This might achieve what you're after:</p>\n...
# 37845  <p>I presume that you want to convert your col...
# 13378  <p>I need to find maximum element from two arr...
# 16590  <p>Ok i was using an old version. Everything i...
# 21649  <p>I created a Twitter app I need user of my A...
# 33962  <p>Let's say I have a reactJS component with a...
# 32027  <p>I'm using properties files in my program. I...
# 28094  <p>In order to flesh this out with more info. ...
# 15727  <blockquote>\n  <p>but in the above case it is...
# 12888  <pre><code>arr = [NSMutableArray array];\n[arr...
# 15325  <p>I was having a discussion with a teammate a...
# 32304  <p>When i am trying to connect to hbase throug...
# 22251  <p>I am working on an e-shop, where an item in...
#
#                                                     Tags        Id  Score  \
# 19387                                                NaN  39118307      7
# 26446                                                NaN   1123040      6
# 31075                                                NaN  57798222      0
# 234    <python-3.x><precision><complex-numbers><compu...  57767349      1
# 30400                <assembly><microcontroller><68hc12>  20100772      0
# 47945                                 <template-haskell>  20106612      0
# 44562                                                NaN  20105588      6
# 27341                                                NaN  20070287      0
# 37845                                                NaN   1163645      1
# 13378                                             <java>  57770879      0
# 16590                                                NaN  39117606      0
# 21649                          <android><twitter><oauth>   1121329      6
# 33962                              <javascript><reactjs>  39145971      1
# 32027                              <java><netbeans><jar>  57798517      0
# 28094                                                NaN   1123866      1
# 15727                                                NaN   1118928      2
# 12888      <objective-c><nsmutablearray><insertion-sort>  20064925      1
# 15325   <c#><.net><multithreading><load><zombie-process>  20065780    406
# 32304                                    <hadoop><hbase>  39145514      0
# 22251                         <jquery><object><jstorage>  39119130      0
#
#        ViewCount  FavoriteCount  AnswerCount
# 19387        NaN            NaN          NaN
# 26446        NaN            NaN          NaN
# 31075        NaN            NaN          NaN
# 234        199.0            NaN          1.0
# 30400     1899.0            NaN          2.0
# 47945       72.0            NaN          1.0
# 44562        NaN            NaN          NaN
# 27341        NaN            NaN          NaN
# 37845        NaN            NaN          NaN
# 13378     3983.0            0.0          5.0
# 16590        NaN            NaN          NaN
# 21649     6804.0            0.0          1.0
# 33962     5948.0            0.0          2.0
# 32027      130.0            NaN          0.0
# 28094        NaN            NaN          NaN
# 15727        NaN            NaN          NaN
# 12888      116.0            NaN          2.0
# 15325    28688.0            0.0          7.0
# 32304      547.0            NaN          1.0
# 22251      241.0            NaN          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          17920 non-null  object
#  1   Body           49970 non-null  object
#  2   Tags           17920 non-null  object
#  3   Id             50000 non-null  int64
#  4   Score          50000 non-null  int64
#  5   ViewCount      17920 non-null  float64
#  6   FavoriteCount  5079 non-null   float64
#  7   AnswerCount    17920 non-null  float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 3.1+ MB

# %%
df.dtypes.value_counts()
# Out:
# object     3
# float64    3
# int64      2
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# Title            17918
# Body             49954
# Tags             14328
# Id               50000
# Score              309
# ViewCount         5772
# FavoriteCount        1
# AnswerCount         35
# dtype: int64

# %% [markdown]
# # NaN et duplicated

# %%
df.isna().sum()
# Out:
# Title            32080
# Body                30
# Tags             32080
# Id                   0
# Score                0
# ViewCount        32080
# FavoriteCount    44921
# AnswerCount      32080
# dtype: int64

# %%
df.isna().mean()
# Out:
# Title            0.64160
# Body             0.00060
# Tags             0.64160
# Id               0.00000
# Score            0.00000
# ViewCount        0.64160
# FavoriteCount    0.89842
# AnswerCount      0.64160
# dtype: float64

# %%
df.isna().mean().sort_values()
# Out:
# Id               0.00000
# Score            0.00000
# Body             0.00060
# Title            0.64160
# Tags             0.64160
# ViewCount        0.64160
# AnswerCount      0.64160
# FavoriteCount    0.89842
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#On garde que les variables les plus importantes:
df=df[['Body','Title','Tags']]
df
# Out:
#                                                     Body  \
# 0      <p>I am building an inline editable form.</p>\...
# 1      <p>I'm going to operate off the assumption tha...
# 2      <p>Use to add the textarea's classes to tinymc...
# 3      <p>It seems to me that unless the compiler can...
# 4      <blockquote>\n  <p>Is the compiler free to ass...
# ...                                                  ...
# 49995  <p>I have these cron tasks to manage the autom...
# 49996  <p>I'm using VS2010, MVC 4 with Razor, JQuery ...
# 49997  <p>I am working on an <code>ASP.NET MVC 4</cod...
# 49998  <p>Can some one help me with puppet, I want to...
# 49999  <p>I have a data frame consisting of two colum...
#
#                                                    Title  \
# 0      angular: assigning ng-options dynamically, str...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49995  Delete files older than 24 hours and empty dir...
# 49996  MVC 4 Jquery Datepicker Initializes on Multipl...
# 49997  How to change the default redirect behaviour o...
# 49998          puppet how to manage service with only if
# 49999  construct a data frame in R from combining inf...
#
#                                                     Tags
# 0                        <javascript><angularjs><select>
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49995                                       <find><cron>
# 49996      <jquery><asp.net-mvc-4><jquery-ui-datepicker>
# 49997  <asp.net-mvc-4><forms-authentication><simpleme...
# 49998            <service><puppet><configurationmanager>
# 49999                                                <r>
#
# [50000 rows x 3 columns]

# %%
df.shape
# Out:
# (50000, 3)

# %%
df.isna().sum()
# Out:
# Body        30
# Title    32080
# Tags     32080
# dtype: int64

# %%
df.describe(include=object)
# Out:
#                                                      Body  \
# count                                               49970
# unique                                              49954
# top     DON'T EVEN THINK OF USING THIS TAG!  It was bu...
# freq                                                    3
#
#                        Title          Tags
# count                  17920         17920
# unique                 17918         14328
# top     Convert Memo to Text  <javascript>
# freq                       2            85

# %%
df.isna().sum()
# Out:
# Id           0
# Body        30
# Title    32080
# Tags     32080
# dtype: int64
